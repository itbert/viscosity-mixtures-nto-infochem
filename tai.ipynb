# %%
import pandas as pd

# %%
smile = "CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO"
data = pd.read_csv('data/NTO_smiles_encoded.csv')

# %%
data2 = pd.read_csv('data/NTO_exp_encoded.csv')

# %%
merged_df = pd.merge(data, data2, on='component_name', how='left')
merged_df
# Out:
#                               component_name      smiles  \
# 0       cf40823a-4b86-415c-b841-a9ead84d9fcf   CCCCC(C)C
# 1       cf40823a-4b86-415c-b841-a9ead84d9fcf   CCCCC(C)C
# 2       cf40823a-4b86-415c-b841-a9ead84d9fcf   CCCCC(C)C
# 3       cf40823a-4b86-415c-b841-a9ead84d9fcf   CCCCC(C)C
# 4       cf40823a-4b86-415c-b841-a9ead84d9fcf   CCCCC(C)C
# ...                                      ...         ...
# 101855  7a1c1a96-1ec2-4582-b69b-f5f66e453dea  CC(C)CCCCC
# 101856  7a1c1a96-1ec2-4582-b69b-f5f66e453dea  CC(C)CCCCC
# 101857  7a1c1a96-1ec2-4582-b69b-f5f66e453dea  CC(C)CCCCC
# 101858  7a1c1a96-1ec2-4582-b69b-f5f66e453dea  CC(C)CCCCC
# 101859  7a1c1a96-1ec2-4582-b69b-f5f66e453dea  CC(C)CCCCC
#
#                                     blend_id  mass_fraction  \
# 0       4290de2b-7013-47c8-aa60-3cff5c960906          4.500
# 1       4290de2b-7013-47c8-aa60-3cff5c960906          4.500
# 2       4290de2b-7013-47c8-aa60-3cff5c960906          4.500
# ...

# %%
result = merged_df[merged_df['smiles'] == smile]
result
# Out:
#                             component_name                             smiles  \
# 7590  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7591  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7592  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7593  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7594  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# ...                                    ...                                ...
# 7695  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7696  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7697  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7698  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
# 7699  240187a5-a150-4a92-9e53-8d964dedf3fb  CC1=CC2=NNN=C2C=C1.C(CO)N(CCO)CCO
#
# ...
